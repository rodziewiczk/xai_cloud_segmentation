# %%
# !pip uninstall -y numpy
# !pip install numpy==1.26.4 --upgrade --force-reinstall
import os
os.kill(os.getpid(), 1)
# Out:
# Found existing installation: numpy 1.26.4
# Uninstalling numpy-1.26.4:
#   Successfully uninstalled numpy-1.26.4
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# gradio 5.50.0 requires pydantic<=2.12.3,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# !pip install captum
# !pip install -q segmentation-models-pytorch captum
import sys
sys.path.append("/content/drive/MyDrive/cloudsen12_models/")
# !pip install -q segmentation-models-pytorch
# %pip install -U captum
# %pip install -U "mercantile>=1,<2"
# %pip install -U segmentation-models-pytorch==0.3.3 timm
# %pip install -U loguru "pydantic>=2.6,<3"
# %pip install -U spyndex
# %pip install -U mlstac==0.1.7
# !{sys.executable} -m pip uninstall -y georeader georeader-spaceml || true
# !{sys.executable} -m pip install -U "shapely>=2,<3" "owslib>=0.28" py7zr validators
# !{sys.executable} -m pip install --no-deps -U "git+https://github.com/spaceml-org/georeader.git@main#egg=georeader"
# !{sys.executable} -m pip install -U "rasterio>=1.4.1"
# !{sys.executable} -m pip uninstall -y georeader georeader-spaceml
# !{sys.executable} -m pip install --no-deps -U "git+https://github.com/spaceml-org/georeader.git@main"
import georeader, importlib.metadata as im
from cloudsen12_models import cloudsen12
import sys
import torch
import sys
import torch
sys.path.append("/content/drive/MyDrive/XAISegmentation/")
sys.path.append("/content/drive/MyDrive/cloudsen12_models/")
from load_patches.load_patches import iter_cloudsen_from_npz
from experiment.xai_experiment import run_xai_experiment_v3
from cloudsen12_models import cloudsen12
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.3 MB/s eta 0:00:00
# ...
# WARNING: Skipping georeader as it is not installed.
# Found existing installation: georeader-spaceml 1.5.9
# Uninstalling georeader-spaceml-1.5.9:
#   Successfully uninstalled georeader-spaceml-1.5.9
# ...
#   Cloning https://github.com/spaceml-org/georeader.git (to revision main) to /tmp/pip-install-yl8qc6wb/georeader_a1f470f485d4468fb5d77d4e8831b549
#   Running command git clone --filter=blob:none --quiet https://github.com/spaceml-org/georeader.git /tmp/pip-install-yl8qc6wb/georeader_a1f470f485d4468fb5d77d4e8831b549
#   Resolved https://github.com/spaceml-org/georeader.git to commit 46ee7195229d609b9bc19c56c800ef103da65777
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   WARNING: Generating metadata for package georeader produced metadata for project name georeader-spaceml. Fix your #egg=georeader fragments.
# ...

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

#model_cloudsen = cloudsen12.load_model_by_name(name="UNetMobV2_V1", weights_folder="cloudsen12_models")
#model_cloudsen.name = "UnetMobV2_V1"

#model_cloudsen = cloudsen12.load_model_by_name(name="UNetMobV2_V2", weights_folder="cloudsen12_models")
#model_cloudsen.name = "UnetMobV2_V2"
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# UNetMobV2_V1.pt:   0%|          | 0.00/26.8M [00:00<?, ?B/s]

# %%
methods_cfg_cloudsen= {

    "lime_noise": {
        "baseline": "noise",
        "sigma_noise": 0.2,
        "n_samples": 100,
        "p": 0.5,
        "lime_batch_size": 3,
        "B_method": 50,
    },
    "vanilla_grad": {
        "use_absolute": True,
        "B_method": 50,
    },

    "smoothgrad": {
        "stdevs": 0.02,
        "nt_samples": 12,
        "nt_samples_batch_size": 1,
        "use_absolute": True,
        "B_method": 50,
    },

    "ig_0": {
        "baseline": "0",
        "n_steps": 20,
        "internal_batch_size": 1,
        "B_method": 50,
    },

    "ig_mean": {
        "baseline": "mean",
        "n_steps": 20,
        "internal_batch_size": 1,
        "B_method": 50,
    },


    "reg_occ_0": {
        "baseline": "0",
        "channel_chunk": 3,
        "B_method": 20,
    },
     "reg_occ_noise": {
        "baseline": "noise",
        "sigma_noise": 0.4,
        "channel_chunk": 3,
        "B_method": 20,
        "n_noise" : 3,
    },


    "reg_occ_mean": {
        "baseline": "mean",
        "channel_chunk": 3,
        "B_method": 20,
    },


    "lime_mean": {
        "baseline": "mean",
        "sigma_noise": 0.0,
        "n_samples": 100,
        "p": 1/3,
        "lime_batch_size": 3,
        "B_method": 50,
    },
    "lime_0": {
        "baseline": "0",
        "sigma_noise": 0.0,
        "n_samples": 100,
        "p": 1/3,
        "lime_batch_size": 3,
        "B_method": 50,
    },
  }


def cloudsen_normalize(x: torch.Tensor) -> torch.Tensor:
    return x / 10000.0


CLOUD_DIR = "/content/drive/MyDrive/data/cloudsen12_data/cloudsen12_npz_13bands/val"
N_CLOUD = 535

run_xai_experiment_v3(
    raw_model=model_cloudsen,
    dataset=iter_cloudsen_from_npz(CLOUD_DIR, start_idx=1, limit=N_CLOUD),
    classes=[0,1,2,3],
    methods_cfg=methods_cfg_cloudsen,
    normalize_fn=cloudsen_normalize,
    pad_to_hw = None,
    pad_mode="constant",
    pad_value=0.0,
    connectivity=4,
    B_pred=100,
    drops_masks_batch_size=100,
    pixel_count=(1/100) * 512 * 512,
    global_seed=124, deterministic=True,
    ccl_workers=8,
    persist_csv_dir="",
    persist_ccl_dir="",
    calculate_metrics=True,
)

# %%
from google.colab import runtime
runtime.unassign()
